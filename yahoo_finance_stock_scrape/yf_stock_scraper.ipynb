# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def scrape_table(url):
    soup = BeautifulSoup(requests.get(url).text)
    headers = [header.text for listing in soup.find_all('thead') for header in listing.find_all('th')]
    raw_data = {header:[] for header in headers}

    for rows in soup.find_all('tbody'):
      for row in rows.find_all('tr'):
        if len(row) != len(headers): continue
        for idx, cell in enumerate(row.find_all('td')):
          raw_data[headers[idx]].append(cell.text)

    return pd.DataFrame(raw_data)

# %%
cryptocurrencies = scrape_table("https://finance.yahoo.com/cryptocurrencies")
currencies = scrape_table("https://finance.yahoo.com/currencies")
commondaties = scrape_table("https://finance.yahoo.com/commodities")
activestocks = scrape_table("https://finance.yahoo.com/most-active")
techstocks = scrape_table("https://finance.yahoo.com/industries/software_services")
gainers = scrape_table("https://finance.yahoo.com/gainers")
losers = scrape_table("https://finance.yahoo.com/losers")
indices = scrape_table("https://finance.yahoo.com/world-indices")

# %%
from datetime import datetime
def convert_column_to_float(df, columns):
  for column in columns: 
      df[column] = pd.to_numeric(df[column].str.replace(',','').str.replace('%',''))
  return df

def convert_column_to_datetime(df, columns):
  for column in columns:
      df[column] = pd.to_datetime(df[column])
  return df

def revert_scaled_number(number):
  mapping = {'M': 1000000, 'B': 1000000000, 'T': 1000000000000}
  scale = number[-1]
  if scale not in ['M','B','T']:
      return float(number.replace(',',''))
  return float(number[0:-1].replace(',','')) * mapping[scale]

# %%
cryptocurrencies = scrape_table("https://finance.yahoo.com/cryptocurrencies")
cryptocurrencies['Market Cap'] = cryptocurrencies['Market Cap'].apply(revert_scaled_number)
cryptocurrencies['Circulating Supply'] = cryptocurrencies['Circulating Supply'].apply(revert_scaled_number)
cryptocurrencies = convert_column_to_float(cryptocurrencies, ['Price (Intraday)'])
cryptocurrencies
# Out:
#        Symbol                  Name  Price (Intraday)     Change % Change  \
# 0     BTC-USD           Bitcoin USD      37043.270000  -1,616.90   -4.18%
# 1     ETH-USD          Ethereum USD       2688.290000    -114.97   -4.10%
# 2    USDT-USD            Tether USD          1.001300    +0.0007   +0.07%
# 3     BNB-USD       BinanceCoin USD        393.850000     -21.57   -5.19%
# 4     ADA-USD           Cardano USD          1.728000    -0.0970   -5.31%
# 5    DOGE-USD          Dogecoin USD          0.384399  -0.005665   -1.45%
# 6     XRP-USD               XRP USD          0.969835  -0.062999   -6.10%
# 7    DOT1-USD          Polkadot USD         25.190000      -1.76   -6.52%
# 8    USDC-USD           USDCoin USD          1.000700    +0.0001   +0.01%
# 9    UNI3-USD           Uniswap USD         26.370000      -1.83   -6.48%
# 10   ICP1-USD  InternetComputer USD        110.400000     -15.62  -12.40%
# 11    BCH-USD       BitcoinCash USD        671.650000     -38.79   -5.46%
# 12   LINK-USD         Chainlink USD         29.170000      -2.74   -8.58%
# 13    LTC-USD          Litecoin USD        178.700000     -11.22   -5.91%
# 14   SOL1-USD            Solana USD         37.700000      -1.82   -4.60%
# 15  MATIC-USD      MaticNetwork USD          1.631300    -0.1749   -9.68%
# 16    HEX-USD               HEX USD          0.058419  +0.005479  +10.35%
# 17  THETA-USD             THETA USD          9.172600    -0.2413   -2.56%
# 18    XLM-USD           Stellar USD          0.387850  -0.030325   -7.25%
# 19    VET-USD           VeChain USD          0.130625  -0.004797   -3.54%
# 20    ETC-USD   EthereumClassic USD         65.080000      -3.62   -5.27%
# 21    FIL-USD   FilecoinFutures USD         90.870000      +2.72   +3.09%
# 22    EOS-USD               EOS USD          6.042200    -0.3464   -5.42%
# 23    TRX-USD              TRON USD          0.077079  -0.002746   -3.44%
# 24    XMR-USD            Monero USD        291.050000     -11.89   -3.92%
#
#       Market Cap Volume in Currency (Since 0:00 UTC)  \
# 0   6.936950e+11                             42.156B
# 1   3.122580e+11                              33.72B
# 2   6.202000e+10                             92.796B
# 3   6.043000e+10                                  5B
# 4   5.520500e+10                               4.54B
# 5   4.992600e+10                              6.126B
# 6   4.475900e+10                              4.574B
# 7   2.380000e+10                              2.889B
# 8   2.283800e+10                              2.606B
# 9   1.490000e+10                            577.645M
# 10  1.370100e+10                            461.781M
# 11  1.259700e+10                              2.475B
# 12  1.255700e+10                              2.042B
# 13  1.192900e+10                              3.077B
# 14  1.027800e+10                              1.139B
# 15  1.026000e+10                              2.441B
# 16  1.013000e+10                              26.94M
# 17  9.173000e+09                              1.074B
# 18  8.970000e+09                            973.957M
# 19  8.401000e+09                              1.898B
# 20  7.570000e+09                              3.411B
# 21  6.933000e+09                              3.063B
# 22  5.764000e+09                              1.966B
# 23  5.523000e+09                              1.625B
# 24  5.217000e+09                            399.005M
#
#    Volume in Currency (24Hr) Total Volume All Currencies (24Hr)  \
# 0                    42.156B                            42.156B
# 1                     33.72B                             33.72B
# 2                    92.796B                            92.796B
# 3                         5B                                 5B
# 4                      4.54B                              4.54B
# 5                     6.126B                             6.126B
# 6                     4.574B                             4.574B
# 7                     2.889B                             2.889B
# 8                     2.606B                             2.606B
# 9                   577.645M                           577.645M
# 10                  461.781M                           461.781M
# 11                    2.475B                             2.475B
# 12                    2.042B                             2.042B
# 13                    3.077B                             3.077B
# 14                    1.139B                             1.139B
# 15                    2.441B                             2.441B
# 16                    26.94M                             26.94M
# 17                    1.074B                             1.074B
# 18                  973.957M                           973.957M
# 19                    1.898B                             1.898B
# 20                    3.411B                             3.411B
# 21                    3.063B                             3.063B
# 22                    1.966B                             1.966B
# 23                    1.625B                             1.625B
# 24                  399.005M                           399.005M
#
#     Circulating Supply 52 Week Range 1 Day Chart
# 0         1.872700e+07
# 1         1.161550e+08
# 2         6.193800e+10
# 3         1.534330e+08
# 4         3.194800e+10
# 5         1.298820e+11
# 6         4.615100e+10
# 7         9.448660e+08
# 8         2.282200e+10
# 9         5.649550e+08
# 10        1.241040e+08
# 11        1.875500e+07
# 12        4.305100e+08
# 13        6.675200e+07
# 14        2.726370e+08
# 15        6.289000e+09
# 16        1.734110e+11
# 17        1.000000e+09
# 18        2.312800e+10
# 19        6.431600e+10
# 20        1.163130e+08
# 21        7.629300e+07
# 22        9.539660e+08
# 23        7.166000e+10
# 24        1.792500e+07

# %%
# first scrape the active stocks table using the web scraper function
activestocks = scrape_table("https://finance.yahoo.com/most-active")
# change the data type of the dataframe columns
activestocks = convert_column_to_float(activestocks, ['% Change'])

# filter the dataframe by % Change (pos/neg)
rising = activestocks[activestocks['% Change'] > 0]
losing = activestocks[activestocks['% Change'] < 0]

# %%
#activestocks
#rising
losing
# Out:
#    Symbol                                    Name Price (Intraday) Change  \
# 0     AMC        AMC Entertainment Holdings, Inc.            47.93  -3.41
# 1      BB                      BlackBerry Limited            13.84  -2.04
# 2       F                      Ford Motor Company            15.94  -0.05
# 4      GE                General Electric Company            13.98  -0.11
# 10   TLRY                            Tilray, Inc.            18.74  -0.98
# 14    TAL                     TAL Education Group            30.01  -3.26
# 15    AAL            American Airlines Group Inc.            24.34  -0.59
# 21   PSTH  Pershing Square Tontine Holdings, Ltd.            21.94  -3.10
# 24     GM                  General Motors Company            63.22  -0.24
#
#     % Change    Volume Avg Vol (3 month) Market Cap PE Ratio (TTM)  \
# 0      -6.64  308.301M          131.546M    24.604B            N/A
# 1     -12.85  163.488M           28.636M     7.836B            N/A
# 2      -0.28  138.025M           78.904M    63.647B          16.04
# 4      -0.82   49.188M           74.455M   122.681B            N/A
# 10     -4.97   33.038M           24.431M     8.361B            N/A
# 14     -9.80   26.838M            7.788M    19.353B            N/A
# 15     -2.37   25.932M           39.118M    15.611B            N/A
# 21    -12.40   20.939M             2.66M     4.389B            N/A
# 24     -0.39   18.637M           18.343M    91.704B          10.20
#
#    52 Week Range
# 0
# 1
# 2
# 4
# 10
# 14
# 15
# 21
# 24

# %%
rising = rising.sort_values(by=['% Change'], ascending=False)
losing = losing.sort_values(by=['% Change'], ascending=True)
